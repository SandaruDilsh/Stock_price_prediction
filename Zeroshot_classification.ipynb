# %%
# !pip install transformers

# %%
# !pip install --upgrade torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 45.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install --upgrade --force-reinstall torchvision torchaudio --no-cache-dir --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 51.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 137.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 92.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 45.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 78.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 80.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 76.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 96.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# Initialize the zero-shot-classification pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# Define your factors (categories)
factors = [
   "Financial updates: Company-specific quarterly, annual, or monthly financial performance reports or statements",
    "Financial: Capital raising activities such as public offerings, loan or lease arrangements, and private placements",
    "Financial: Dividend Declared",
    "Financial: Annual and quater meetings",
    "Technical: Discovery of Gold",
    "Operational: Expansion of mining operations (including M&A)",
    "Operational: Opening or closure of mining",
    "Operational updates: Changes in production output or efficiency",
    "Operational: Changes in key management positions",
    "Regulatory: Updates on lawsuits or penalties, compliance with regulatory standards, sustainability and corporate governance",
    "Regulatory: Approval or rejection of mining permits & licenses",
    "Geopolitical events: Political instability or conflicts",
]

# Function to classify input text into one or more factors
def classify_text(article_text):
    result = classifier(article_text, factors, multi_label=True)

    # Display the results
    print("\nClassification Results:")
    for label, score in zip(result["labels"], result["scores"]):
        print(f"{label}: {score:.2f}")

    # Return the top factor(s)
    print("\nMost Relevant Factor(s):")
    max_score = max(result["scores"])
    for label, score in zip(result["labels"], result["scores"]):
        if score == max_score:
            print(f"{label}: {score:.2f}")
    return result

# Example usage
if __name__ == "__main__":
    # Input text from an article
    article_text = input("Enter the text of the article:\n")

    # Classify the text
    classify_text(article_text)
# Out:
# Device set to use cpu
# Enter the text of the article:
# CONTANGO ORE, INC. Announces Results of the 2023 Virtual Annual Meeting of Stockholders and Results for the Quarter Ended September 30, 2023
#
# Classification Results:
# Financial: Annual and quater meetings: 0.98
# Financial updates: Company-specific quarterly, annual, or monthly financial performance reports or statements: 0.97
# Financial: Capital raising activities such as public offerings, loan or lease arrangements, and private placements: 0.80
# Operational updates: Changes in production output or efficiency: 0.55
# Financial: Dividend Declared: 0.45
# Operational: Opening or closure of mining: 0.30
# Operational: Changes in key management positions: 0.30
# Regulatory: Updates on lawsuits or penalties, compliance with regulatory standards, sustainability and corporate governance: 0.27
# Regulatory: Approval or rejection of mining permits & licenses: 0.16
# Technical: Discovery of Gold: 0.15
# ...
